# %% [markdown]
# # Pandas 연습문제

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
mpg = sns.load_dataset('mpg')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1번 - Iris
# 1. 붓꽃 종(species)별로 꽃잎길이(sepal_length), 꽃잎폭(sepal_width),
# 꽃받침길이(petal_length), 꽃받침폭(petal_width)의 평균, 표준편차 등
# 기초통계량(describe())을 구하시오.
# 2. 3분위수(Q3)와 1분위수(Q1)의 차이보다 1.5배가 크거나 작은 데이터는 이상치이다.
# 즉,
# Q1 - 1.5 * (Q3 - Q1) 보다 작은 데이터
# Q3 + 1.5 * (Q3 - Q1) 보다 큰 데이터
# 이 이상치를 제거하고 위의 4가지 항목에 대해서 평균, 표준편차를 구하시오.

# %% [markdown]
# ### 1-1

# %%
iris.groupby('species').agg(['mean','std'])
# Out:
#            sepal_length           sepal_width  ... petal_length petal_width
#                    mean       std        mean  ...          std        mean       std
# species                                        ...
# setosa            5.006  0.352490       3.428  ...     0.173664       0.246  0.105386
# versicolor        5.936  0.516171       2.770  ...     0.469911       1.326  0.197753
# virginica         6.588  0.635880       2.974  ...     0.551895       2.026  0.274650
#
# [3 rows x 8 columns]

# %% [markdown]
# ### 1-2

# %%
s = iris[iris.species=='setosa']['sepal_width']
s.mean(), s.std()
# Out:
# (3.428000000000001, 0.3790643690962886)

# %%
q1, q3 = s.quantile(.25), s.quantile(.75)
iqr = q3 - q1
q1, q3, iqr
# Out:
# (3.2, 3.6750000000000003, 0.4750000000000001)

# %%
lower = q1 - 1.5*iqr
upper = q3 + 1.5*iqr
s[(s < lower )| (s > upper)] = np.nan    # 이상치에 해당하는 값을 nan으로 변경
s.isnull().sum()    # 이상치 수
# Out:
# 2

# %%
s.mean(), s.std()
# Out:
# (3.4312500000000004, 0.32034306743094015)

# %%
def get_new_stat(s):
    q1, q3 = s.quantile(.25), s.quantile(.75)
    iqr = q3 - q1
    lower = q1 - 1.5*iqr
    upper = q3 + 1.5*iqr
    s[(s < lower )| (s > upper)] = np.nan
    outlier = s.isnull().sum() != 0
    return outlier, np.round(s.mean(), 2), np.round(s.std(), 2)

# %%
species_list, feature_list, mean_list, std_list = [], [], [], []
outlier_list, new_mean_list, new_std_list = [], [], []

for species in iris.species.unique():
    for feature in iris.columns[:-1]:
        s = iris[iris.species == species][feature]
        species_list.append(species)
        feature_list.append(feature)
        mean_list.append(np.round(s.mean(),2))
        std_list.append(np.round(s.std(),4))

        outlier, new_mean, new_std = get_new_stat(s)
        outlier_list.append(outlier)
        new_mean_list.append(new_mean)
        new_std_list.append(new_std)

# %%
df = pd.DataFrame({
    'species' : species_list, 'feature' : feature_list,
    'mean' : mean_list, 'std' : std_list,
    'outlier' : outlier_list, 'new_mean' : new_mean_list, 'new_std' : new_std_list
})
df.set_index(['species','feature'], inplace=True)
df
# Out:
#                          mean     std  outlier  new_mean  new_std
# species    feature
# setosa     sepal_length  5.01  0.3525    False      5.01     0.35
#            sepal_width   3.43  0.3791     True      3.43     0.32
#            petal_length  1.46  0.1737     True      1.46     0.13
#            petal_width   0.25  0.1054     True      0.23     0.09
# versicolor sepal_length  5.94  0.5162    False      5.94     0.52
#            sepal_width   2.77  0.3138    False      2.77     0.31
#            petal_length  4.26  0.4699     True      4.29     0.44
#            petal_width   1.33  0.1978    False      1.33     0.20
# virginica  sepal_length  6.59  0.6359     True      6.62     0.59
#            sepal_width   2.97  0.3225     True      2.96     0.26
#            petal_length  5.55  0.5519    False      5.55     0.55
#            petal_width   2.03  0.2747    False      2.03     0.27

# %% [markdown]
# ## 2번 - 타이타닉
# 1. 타이타닉호의 승객에 대해 나이와 성별에 의한 카테고리 열인 category1 열을 만드시오.
# category1 카테고리는 다음과 같이 정의됨
# 1) 20살이 넘으면 성별을 그대로 사용한다.
# 2) 20살 미만이면 성별에 관계없이 “child”라고 한다.
# 2. 타이타닉호의 승객 중 나이를 명시하지 않은 고객은 나이를 명시한 고객의 평균 나이 값
# 이 되도록 titanic 데이터프레임을 고치시오.
# 3. 성별, 선실(class)별, 출발지(embark_town)별 생존율을 구하시오.
# 4. 타이타닉호 승객을 ‘미성년자’, ‘청년’, ‘중년’, ‘장년’, ‘노년’ 나이 그룹으로 나누고,
# 각 그룹별 생존율을 구하시오.
# bins = [1, 20, 30, 50, 70, 100]
# labels = ["미성년자", "청년", "중년", "장년", "노년"]
# 5. qcut 명령으로 세 개의 나이 그룹을 만들고, 나이 그룹별 남녀 성비와 생존율을 구하시오.

# %% [markdown]
# ### 2-1

# %%
titanic['category1'] = [titanic.sex[i] if titanic.age[i]>=20 else 'child' for i in range(len(titanic))]
titanic.head(10)
# Out:
#    survived  pclass     sex   age  ...  embark_town  alive  alone category1
# 0         0       3    male  22.0  ...  Southampton     no  False      male
# 1         1       1  female  38.0  ...    Cherbourg    yes  False    female
# 2         1       3  female  26.0  ...  Southampton    yes   True    female
# 3         1       1  female  35.0  ...  Southampton    yes  False    female
# 4         0       3    male  35.0  ...  Southampton     no   True      male
# 5         0       3    male   NaN  ...   Queenstown     no   True     child
# 6         0       1    male  54.0  ...  Southampton     no   True      male
# 7         0       3    male   2.0  ...  Southampton     no  False     child
# 8         1       3  female  27.0  ...  Southampton    yes  False    female
# 9         1       2  female  14.0  ...    Cherbourg    yes  False     child
#
# [10 rows x 16 columns]

# %%
# 강사님 풀이
titanic['category1'] = titanic.apply(lambda r: r.sex if r.age>=20 else 'child', axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  ...  embark_town  alive  alone category1
# 886         0       2    male  27.0  ...  Southampton     no   True      male
# 887         1       1  female  19.0  ...  Southampton    yes   True     child
# 888         0       3  female   NaN  ...  Southampton     no  False     child
# 889         1       1    male  26.0  ...    Cherbourg    yes   True      male
# 890         0       3    male  32.0  ...   Queenstown     no   True      male
#
# [5 rows x 16 columns]

# %% [markdown]
# ### 2-2

# %%
titanic.age.fillna(np.round(np.mean(titanic.age), 1), inplace=True) 
titanic.head(10)
# Out:
#    survived  pclass     sex   age  ...  embark_town  alive  alone category1
# 0         0       3    male  22.0  ...  Southampton     no  False      male
# 1         1       1  female  38.0  ...    Cherbourg    yes  False    female
# 2         1       3  female  26.0  ...  Southampton    yes   True    female
# 3         1       1  female  35.0  ...  Southampton    yes  False    female
# 4         0       3    male  35.0  ...  Southampton     no   True      male
# 5         0       3    male  29.7  ...   Queenstown     no   True     child
# 6         0       1    male  54.0  ...  Southampton     no   True      male
# 7         0       3    male   2.0  ...  Southampton     no  False     child
# 8         1       3  female  27.0  ...  Southampton    yes  False    female
# 9         1       2  female  14.0  ...    Cherbourg    yes  False     child
#
# [10 rows x 16 columns]

# %%
titanic['age'] = titanic.age.fillna(titanic.age.mean())
titanic.tail()
# Out:
#      survived  pclass     sex   age  ...  embark_town  alive  alone category1
# 886         0       2    male  27.0  ...  Southampton     no   True      male
# 887         1       1  female  19.0  ...  Southampton    yes   True     child
# 888         0       3  female  29.7  ...  Southampton     no  False     child
# 889         1       1    male  26.0  ...    Cherbourg    yes   True      male
# 890         0       3    male  32.0  ...   Queenstown     no   True      male
#
# [5 rows x 16 columns]

# %%
titanic['category1'] = titanic.apply(lambda r: r.sex if r.age>=20 else 'child', axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  ...  embark_town  alive  alone category1
# 886         0       2    male  27.0  ...  Southampton     no   True      male
# 887         1       1  female  19.0  ...  Southampton    yes   True     child
# 888         0       3  female  29.7  ...  Southampton     no  False    female
# 889         1       1    male  26.0  ...    Cherbourg    yes   True      male
# 890         0       3    male  32.0  ...   Queenstown     no   True      male
#
# [5 rows x 16 columns]

# %% [markdown]
# ### 2-3

# %%
titanic.groupby('sex')[['survived']].mean() # # titanic.pivot_table('survived', 'sex')
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic.groupby('class')[['survived']].mean() # # titanic.pivot_table('survived', 'class')
# Out:
#         survived
# class
# First   0.629630
# Second  0.472826
# Third   0.242363

# %%
titanic.groupby('embark_town')[['survived']].mean() # titanic.pivot_table('survived', 'embark_town')
# Out:
#              survived
# embark_town
# Cherbourg    0.553571
# Queenstown   0.389610
# Southampton  0.336957

# %%
# 'alive' : 범주형 --> 'survived' : 정수 사용
titanic.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic.pivot_table('survived', ['sex', 'class'], 'embark_town')
# Out:
# embark_town    Cherbourg  Queenstown  Southampton
# sex    class
# female First    0.976744    1.000000     0.958333
#        Second   1.000000    1.000000     0.910448
#        Third    0.652174    0.727273     0.375000
# male   First    0.404762    0.000000     0.354430
#        Second   0.200000    0.000000     0.154639
#        Third    0.232558    0.076923     0.128302

# %%
titanic.pivot_table('survived', ['sex', 'class'])
# Out:
#                survived
# sex    class
# female First   0.968085
#        Second  0.921053
#        Third   0.500000
# male   First   0.368852
#        Second  0.157407
#        Third   0.135447

# %% [markdown]
# ### 2-4

# %%
bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "중년", "장년", "노년"]
titanic['age_cat'] = pd.cut(titanic.age, bins, labels=labels)
titanic.tail()
# Out:
#      survived  pclass     sex   age  ...  alive  alone  category1 age_cat
# 886         0       2    male  27.0  ...     no   True       male      청년
# 887         1       1  female  19.0  ...    yes   True      child    미성년자
# 888         0       3  female  29.7  ...     no  False     female      청년
# 889         1       1    male  26.0  ...    yes   True       male      청년
# 890         0       3    male  32.0  ...     no   True       male      중년
#
# [5 rows x 17 columns]

# %%
titanic.groupby('age_cat')[['survived']].mean() # titanic.pivot_table('survived', 'age_cat')
# Out:
#          survived
# age_cat
# 미성년자     0.424242
# 청년       0.334152
# 중년       0.423237
# 장년       0.355932
# 노년       0.200000

# %%
titanic.pivot_table('survived', ['sex', 'age_cat'])
# Out:
#                 survived
# sex    age_cat
# female 미성년자     0.671233
#        청년       0.723881
#        중년       0.779070
#        장년       0.941176
# male   미성년자     0.228261
#        청년       0.142857
#        중년       0.225806
#        장년       0.119048
#        노년       0.200000

# %% [markdown]
# ### 2-5

# %%
titanic['age_group'] = pd.qcut(titanic.age, 3, labels=['young', 'middle', 'old'])
titanic.tail()
# Out:
#      survived  pclass     sex   age  ...  alone  category1  age_cat age_group
# 886         0       2    male  27.0  ...   True       male       청년    middle
# 887         1       1  female  19.0  ...   True      child     미성년자     young
# 888         0       3  female  29.7  ...  False     female       청년    middle
# 889         1       1    male  26.0  ...   True       male       청년    middle
# 890         0       3    male  32.0  ...   True       male       중년       old
#
# [5 rows x 18 columns]

# %%
titanic.groupby('age_group')[['survived']].mean()
# Out:
#            survived
# age_group
# young      0.411960
# middle     0.335526
# old        0.405594

# %%
# gender : 남성이면 1, 여성이면 0
titanic['gender'] = titanic.apply(lambda r: 1 if r.sex == 'male' else 0, axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  ...  category1  age_cat  age_group gender
# 886         0       2    male  27.0  ...       male       청년     middle      1
# 887         1       1  female  19.0  ...      child     미성년자      young      0
# 888         0       3  female  29.7  ...     female       청년     middle      0
# 889         1       1    male  26.0  ...       male       청년     middle      1
# 890         0       3    male  32.0  ...       male       중년        old      1
#
# [5 rows x 19 columns]

# %%
titanic.pivot_table('gender', 'age_group')
# Out:
#              gender
# age_group
# young      0.594684
# middle     0.680921
# old        0.667832

# %%
titanic.pivot_table(['gender', 'survived'], 'age_group')
# Out:
#              gender  survived
# age_group
# young      0.594684  0.411960
# middle     0.680921  0.335526
# old        0.667832  0.405594

# %% [markdown]
# ## 3번 - Mile Per Gallon
# 1. 배기량(displacement) 대비 마력(horsepower) 열(hp_per_cc)을 추가하시오.
# 2. name으로부터 manufacturer(제조사)와 모델을 추출하여
# 새로운 열 manufacturer와 model을 추가하고, name 열은 삭제하시오.
# 3. 엔진의 실린더(cylinders) 갯수별 연비(mpg)의 평균을 구하시오.
# 4. 생산지(origin)별 배기량 대비 마력(hp_per_cc)의 평균을 구하시오.
# 5. 모델이 5개 이상인 제조사에 대하여
# 연비(mpg)의 평균이 가장 좋은 제조사 Top 5를 구하시오.

# %% [markdown]
# ### 3-1

# %%
mpg['hp_per_cc'] = mpg.horsepower / mpg.displacement
mpg.head()
# Out:
#     mpg  cylinders  displacement  ...  origin                       name  hp_per_cc
# 0  18.0          8         307.0  ...     usa  chevrolet chevelle malibu   0.423453
# 1  15.0          8         350.0  ...     usa          buick skylark 320   0.471429
# 2  18.0          8         318.0  ...     usa         plymouth satellite   0.471698
# 3  16.0          8         304.0  ...     usa              amc rebel sst   0.493421
# 4  17.0          8         302.0  ...     usa                ford torino   0.463576
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 3-2

# %%
mpg['manufacturer'] = mpg.name.apply(lambda x: x.split()[0])

# %%
mpg['model'] = mpg.name.apply(lambda x: ' '.join(x.split()[1:]))

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  ...  hp_per_cc  manufacturer            model
# 0  18.0          8         307.0  ...   0.423453     chevrolet  chevelle malibu
# 1  15.0          8         350.0  ...   0.471429         buick      skylark 320
# 2  18.0          8         318.0  ...   0.471698      plymouth        satellite
# 3  16.0          8         304.0  ...   0.493421           amc        rebel sst
# 4  17.0          8         302.0  ...   0.463576          ford           torino
#
# [5 rows x 12 columns]

# %%
del mpg['name']

# %% [markdown]
# ### 3-3

# %%
mpg.groupby('cylinders')[['mpg']].mean() # mpg[['cylinders','mpg']].groupby('cylinders').mean(), mpg.pivot_table('mpg', 'cylinders')
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %% [markdown]
# ### 3-4

# %%
mpg.pivot_table('hp_per_cc', 'origin')
# Out:
#         hp_per_cc
# origin
# europe   0.740005
# japan    0.789485
# usa      0.512063

# %% [markdown]
# ### 3-5

# %%
mpg.manufacturer.value_counts()
# Out:
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# mazda            10
# oldsmobile       10
# peugeot           8
# fiat              8
# audi              7
# volvo             6
# chrysler          6
# vw                6
# renault           5
# saab              4
# opel              4
# subaru            4
# chevy             3
# cadillac          2
# bmw               2
# mercedes-benz     2
# maxda             2
# toyouta           1
# hi                1
# mercedes          1
# chevroelt         1
# triumph           1
# vokswagen         1
# capri             1
# nissan            1
# Name: manufacturer, dtype: int64

# %%
s = mpg.manufacturer.value_counts()
big = s[s>=5].index.tolist()      # tolist() : list자료형으로 변환
print(big)
# Out:
# ['ford', 'chevrolet', 'plymouth', 'amc', 'dodge', 'toyota', 'datsun', 'buick', 'pontiac', 'volkswagen', 'honda', 'mercury', 'mazda', 'oldsmobile', 'peugeot', 'fiat', 'audi', 'volvo', 'chrysler', 'vw', 'renault']

# %%
# DataFrame에서는 in연산자 대신에 isin() method 사용
mpg[mpg.manufacturer.isin(big)].head()
# Out:
#     mpg  cylinders  displacement  ...  hp_per_cc  manufacturer            model
# 0  18.0          8         307.0  ...   0.423453     chevrolet  chevelle malibu
# 1  15.0          8         350.0  ...   0.471429         buick      skylark 320
# 2  18.0          8         318.0  ...   0.471698      plymouth        satellite
# 3  16.0          8         304.0  ...   0.493421           amc        rebel sst
# 4  17.0          8         302.0  ...   0.463576          ford           torino
#
# [5 rows x 11 columns]

# %%
big_mpg = mpg[mpg.manufacturer.isin(big)]
big_mpg.pivot_table('mpg', 'manufacturer')
# Out:
#                     mpg
# manufacturer
# amc           18.246429
# audi          26.714286
# buick         19.182353
# chevrolet     20.472093
# chrysler      17.266667
# datsun        31.113043
# dodge         22.060714
# fiat          28.912500
# ford          19.694118
# honda         33.761538
# mazda         30.860000
# mercury       19.118182
# oldsmobile    21.100000
# peugeot       23.687500
# plymouth      21.703226
# pontiac       20.012500
# renault       32.880000
# toyota        28.372000
# volkswagen    29.106667
# volvo         21.116667
# vw            39.016667

# %%
big_mpg.pivot_table('mpg', 'manufacturer').sort_values(by='mpg', ascending=False).head() # 내림차순 정렬 : sort_values() 사용
# Out:
#                     mpg
# manufacturer
# vw            39.016667
# honda         33.761538
# renault       32.880000
# datsun        31.113043
# mazda         30.860000

# %% [markdown]
# - filter 사용

# %%
mpg.groupby('manufacturer').filter(lambda x: x.manufacturer.count() >= 5).head()
# Out:
#     mpg  cylinders  displacement  ...  hp_per_cc  manufacturer            model
# 0  18.0          8         307.0  ...   0.423453     chevrolet  chevelle malibu
# 1  15.0          8         350.0  ...   0.471429         buick      skylark 320
# 2  18.0          8         318.0  ...   0.471698      plymouth        satellite
# 3  16.0          8         304.0  ...   0.493421           amc        rebel sst
# 4  17.0          8         302.0  ...   0.463576          ford           torino
#
# [5 rows x 11 columns]

# %%
new_mpg = mpg.groupby('manufacturer').filter(lambda x: x.manufacturer.count() >= 5).head()
new_mpg.pivot_table('mpg', 'manufacturer').sort_values(by='mpg', ascending=False).head()
# Out:
#                mpg
# manufacturer
# chevrolet     18.0
# plymouth      18.0
# ford          17.0
# amc           16.0
# buick         15.0
