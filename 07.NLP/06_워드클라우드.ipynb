# %% [markdown]
# # 워드 클라우드

# %%
# 한글 폰트 설치
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > /dev/null
# !rm -rf ~/.cache/matplotlib > /dev/null
# 런타임 다시 시작

# %%
# !pip install konlpy > /dev/null

# %%
from google.colab import files
uploaded = files.upload()
textfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-739f1d95-27a6-4910-9a74-afb19a0352ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-739f1d95-27a6-4910-9a74-afb19a0352ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gift.txt to gift.txt

# %%
uploaded = files.upload()
maskfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-d22ffb40-1503-4da2-860f-c148bff2c1a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d22ffb40-1503-4da2-860f-c148bff2c1a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.jpg to heart.jpg

# %% [markdown]
# ## 한글 텍스트 전처리

# %%
with open(textfile) as fp:
    text = fp.read()

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
tokens = okt.nouns(text)
tokens[:10]
# Out:
# ['반지', '목걸이', '커플', '가디건', '커플', '모자', '신지', '몇개', '추천', '제품']

# %%
# 영문자, 숫자 제거
import re
new_tokens = []
for token in tokens:
    gift = re.sub('[A-Za-z0-9]', '', token) # \w와 동일
    if gift:
        new_tokens.append(gift)

# %%
# 한글 폰트 사용
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# - 아래 두 과정을 반복해서 불용어를 정리

# %%
gift = nltk.Text(new_tokens, name='여친선물')
plt.figure(figsize=(15,6))
gift.plot(50)
plt.show()

# %%
stoptext = """
    선물 추천 것 가격 수 기능 제품 저 제 생각 여자 분 여자친구 여친 요 더 사용 구매 고급
    판매 때 참고 머리 하나 해 한번 제작 용 준 디자인 거 네이버 사람 배송 중 정말 후기 티니 개 감동
    하트 커플 가능 사랑 세대 인기 상품 직접 브랜드 선택 꿋 모양 마감 요즘 오늘 가지 남녀 그냥 이벤트 위 페이
    마음 부담 로티 남자 협찬 의미 변경 도움 색상 아래 포장 처 조금 하루 정도 처리 보시 꽃말 심플 여성 가장
    
"""
stop_words = stoptext.split()
new_tokens = [word for word in new_tokens if word not in stop_words]
new_tokens[:10]
# Out:
# ['반지', '목걸이', '가디건', '모자', '신지', '몇개', '투척', '클래식', '커플룩', '버핏']

# %% [markdown]
# ## 워드 클라우드 그리기

# %%
from wordcloud import WordCloud
from PIL import Image

# %%
data = gift.vocab().most_common(300)
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
wc = WordCloud(
    font_path=path, relative_scaling=0.2,
    background_color='white'
).generate_from_frequencies(dict(data))

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# - 하트 그림에 표시

# %%
mask = np.array(Image.open(maskfile))
from wordcloud import ImageColorGenerator
image_colors = ImageColorGenerator(mask) # 이미지 color에 맞춰서 색깔을 생성

# %%
wc = WordCloud(
    font_path=path, relative_scaling=0.2,
    background_color='white', mask=mask, 
    min_font_size=1, max_font_size=120
).generate_from_frequencies(dict(data))

# %%
plt.figure(figsize=(10,10))
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis('off')
plt.show()
